# %% [markdown]
# Подключение библиотек

# %%
import numpy as np
import pandas as pd
import sklearn.linear_model as lm
import statsmodels.api as sm
import patsy as pt
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image
from math import sqrt
import statistics
from scipy import stats

# %% [markdown]
# # Задача 3.5

# %%
Image("./Доп задача 3.20.png")

# %% [markdown]
# По проностической силе 2 нельзя сравнить с остаточным.
#
# Посчитаем для 1,3,4 скореллированный на число регрессоров коэффициентов детерминации
#
# $R_{adj}^2 = 1 -(1-R^2) \frac{n-1}{n-k}$
#
# 1)$R_{adj_1}^2 = 0.37$
#
# 3)$R_{adj_3}^2 = 0.57$
#
# 4)$R_{adj_4}^2 = 0.6$
#
# Тогда $R_{adj_1}^2 < R_{adj_3}^2 < R_{adj_4}^2$
#
# Нет незначительных коэффициентов

# %% [markdown]
# А теперь зададимя вопросом: существенны ли коэффициенты при edu?
#
# std=0.35
#
# t(36;0.025) = 14.401
#
# t = $\frac{0.6}{0.35}$ = 1.714
#
# несущественны коэффициенты при exp
#
# t = $\frac{0.2}{0.13}$ = 1.538
#
# Тогда получаем, что 4- не качественн., а остальные качественные
